// %%
3+5
// Out:
// 8

// %%
import * as Plot from "npm:@observablehq/plot";
import { penguins, document } from "jsr:@ry/jupyter-helper";
const p = await penguins();
p

// %%
const x = "culmen_length_mm";
const y = "flipper_length_mm";
Plot.plot({
    marks: [ Plot.dot(p.toRecords(), { x, y, fill: "species" } ) ],
    document
});

// %%
import { tree } from "jsr:@soisfranc/ls";

const files = await tree("../..");
Plot.plot({
    marks: [ Plot.tree(files) ],
    axis: null,
    margin: 100,
    document
});
// Out:
// Stack trace:
// ReferenceError: Plot is not defined
//     at <anonymous>:3:1
//     at eventLoopTick (ext:core/01_core.js:175:7)
